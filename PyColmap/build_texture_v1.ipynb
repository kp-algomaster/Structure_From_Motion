# %%
import os
import pycolmap
import numpy as np
import open3d as o3d

# Set the path to the dataset
# dataset_path = "/Users/kp/Workspace/Git_Repos/Structure_From_Motion/Datasets/fountain"
dataset_path = ".././Datasets/fountain"
# Create a COLMAP database
database_path = os.path.join(dataset_path, "database.db")
db = pycolmap.Database(database_path)

# Configure SIFT feature extraction options
sift_options = pycolmap.SiftExtractionOptions()
sift_options.max_num_features = 8192
sift_options.first_octave = -1
sift_options.num_octaves = 4

# Configure image reader options
reader_options = pycolmap.ImageReaderOptions()

# Extract features
pycolmap.extract_features(database_path, dataset_path, image_list=[],
                          camera_mode=pycolmap.CameraMode.AUTO,
                          camera_model="OPENCV",
                          reader_options=reader_options,
                          sift_options=sift_options)

# Match features
pycolmap.match_exhaustive(database_path)

# Configure incremental mapping options
pipeline_options = pycolmap.IncrementalPipelineOptions()
pipeline_options.mapper.num_threads = 4
pipeline_options.mapper.init_min_num_inliers = 100
pipeline_options.mapper.abs_pose_min_num_inliers = 30
pipeline_options.mapper.abs_pose_min_inlier_ratio = 0.25

# Set up output path
output_path = os.path.join(dataset_path, "reconstruction")
os.makedirs(output_path, exist_ok=True)

# Run incremental mapping
reconstructions = pycolmap.incremental_mapping(database_path, dataset_path, output_path, options=pipeline_options)

if reconstructions:
    reconstruction = next(iter(reconstructions.values()))
    print(f"Reconstruction completed and saved to {output_path}")
    print(f"Number of registered images: {reconstruction.num_reg_images()}")
    print(f"Number of 3D points: {reconstruction.num_points3D()}")

    # Save reconstruction as text files
    reconstruction.write_text(output_path)

    # Prepare point cloud data
    points = []
    colors = []

    for point3D_id in reconstruction.points3D:
        point3D = reconstruction.points3D[point3D_id]
        points.append(point3D.xyz)
        colors.append(point3D.color)

    points = np.array(points)
    colors = np.array(colors)

    # Create Open3D point cloud
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(points)
    pcd.colors = o3d.utility.Vector3dVector(colors / 255.0)

    # Post-processing: downsampling and outlier removal
    pcd = pcd.voxel_down_sample(voxel_size=0.01)
    pcd, _ = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)

    # Save point cloud as PLY file
    ply_path = os.path.join(output_path, "reconstruction.ply")
    o3d.io.write_point_cloud(ply_path, pcd)
    print(f"Point cloud saved as PLY file: {ply_path}")

    # Visualize the point cloud
    o3d.visualization.draw_geometries([pcd])

else:
    print("No reconstruction was created.")
# Out:
# W20240818 21:35:47.366699 0x1f5cd0f40 feature_extraction.cc:406] Your current options use the maximum number of threads on the machine to extract features. Extracting SIFT features on the CPU can consume a lot of RAM per thread for large images. Consider reducing the maximum image size and/or the first octave or manually limit the number of extraction threads. Ignore this warning, if your machine has sufficient memory for the current settings.
# I20240818 21:35:47.366809 0x3108eb000 misc.cc:198]
# ==============================================================================
# Feature extraction
# ==============================================================================
# I20240818 21:35:47.366995 0x3636fb000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:35:47.367008 0x364627000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:35:47.367015 0x3646b3000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:35:47.367029 0x364913000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:35:47.367037 0x364887000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:35:47.367038 0x36499f000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:35:47.367048 0x364e87000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:35:47.367057 0x364f13000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:35:47.367064 0x364f9f000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:35:47.367070 0x365187000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:35:47.367085 0x365213000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21
 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21:35:47.369154 0x36532b000 feature_extraction.cc:257] Processed file [17/42]
# I20240818 21:35:47.369161 0x36532b000 feature_extraction.cc:260]   Name:            0007.png.camera
# E20240818 21:35:47.369164 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47.369194 0x36532b000 feature_extraction.cc:257] Processed file [18/42]
# I20240818 21:35:47.369197 0x36532b000 feature_extraction.cc:260]   Name:            0008.png
# I20240818 21:35:47.369200 0x36532b000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21:35:47.369345 0x36532b000 feature_extraction.cc:257] Processed file [19/42]
# I20240818 21:35:47.369357 0x36532b000 feature_extraction.cc:260]   Name:            0008.png.camera
# E20240818 21:35:47.369362 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47.369388 0x36532b000 feature_extraction.cc:257] Processed file [20/42]
# I20240818 21:35:47.369392 0x36532b000 feature_extraction.cc:260]   Name:            0009.png
# I20240818 21:35:47.369395 0x36532b000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21:35:47.369496 0x36532b000 feature_extraction.cc:257] Processed file [21/42]
# I20240818 21:35:47.369504 0x36532b000 feature_extraction.cc:260]   Name:            0009.png.camera
# E20240818 21:35:47.369507 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47.369543 0x36532b000 feature_extraction.cc:257] Processed file [22/42]
# I20240818 21:35:47.369549 0x36532b000 feature_extraction.cc:260]   Name:            0010.png
# I20240818 21:35:47.369552 0x36532b000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21:35:47.369555 0x36532b000 feature_extraction.cc:257] Processed file [23/42]
# I20240818 21:35:47.369558 0x36532b000 feature_extraction.cc:260]   Name:            0011.png
# I20240818 21:35:47.369561 0x36532b000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21:35:47.369654 0x36532b000 feature_extraction.cc:257] Processed file [24/42]
# I20240818 21:35:47.369660 0x36532b000 feature_extraction.cc:260]   Name:            database.db
# E20240818 21:35:47.369664 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47.369789 0x36532b000 feature_extraction.cc:257] Processed file [25/42]
# I20240818 21:35:47.369793 0x36532b000 feature_extraction.cc:260]   Name:            database.db-shm
# E20240818 21:35:47.369797 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47.369918 0x36532b000 feature_extraction.cc:257] Processed file [26/42]
# I20240818 21:35:47.369922 0x36532b000 feature_extraction.cc:260]   Name:            database.db-wal
# E20240818 21:35:47.369925 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47.370052 0x36532b000 feature_extraction.cc:257] Processed file [27/42]
# I20240818 21:35:47.370056 0x36532b000 feature_extraction.cc:260]   Name:            reconstruction/.DS_Store
# E20240818 21:35:47.370059 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47.370180 0x36532b000 feature_extraction.cc:257] Processed file [28/42]
# I20240818 21:35:47.370183 0x36532b000 feature_extraction.cc:260]   Name:            reconstruction/0/cameras.bin
# E20240818 21:35:47.370186 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47.370316 0x36532b000 feature_extraction.cc:257] Processed file [29/42]
# I20240818 21:35:47.370319 0x36532b000 feature_extraction.cc:260]   Name:            reconstruction/0/images.bin
# E20240818 21:35:47.370322 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47.370452 0x36532b000 feature_extraction.cc:257] Processed file [30/42]
# I20240818 21:35:47.370455 0x36532b000 feature_extraction.cc:260]   Name:            reconstruction/0/points3D.bin
# E20240818 21:35:47.370460 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47.370578 0x36532b000 feature_extraction.cc:257] Processed file [31/42]
# I20240818 21:35:47.370581 0x36532b000 feature_extraction.cc:260]   Name:            reconstruction/cameras.txt
# E20240818 21:35:47.370584 0x36532b000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:35:47
# I20240818 21:35:47.375701 0x1f5cd0f40 incremental_mapper.cc:225] Loading database
# I20240818 21:35:47.375981 0x1f5cd0f40 database_cache.cc:65] Loading cameras...
# I20240818 21:35:47.375995 0x1f5cd0f40 database_cache.cc:75]  11 in 0.000s
# I20240818 21:35:47.375999 0x1f5cd0f40 database_cache.cc:83] Loading matches...
# I20240818 21:35:47.376446 0x1f5cd0f40 database_cache.cc:89]  55 in 0.000s
# I20240818 21:35:47.376450 0x1f5cd0f40 database_cache.cc:105] Loading images...
# I20240818 21:35:47.378633 0x1f5cd0f40 database_cache.cc:155]  11 in 0.002s (connected 11)
# I20240818 21:35:47.378640 0x1f5cd0f40 database_cache.cc:166] Building correspondence graph...
# I20240818 21:35:47.394069 0x1f5cd0f40 database_cache.cc:195]  in 0.015s (ignored 0)
# I20240818 21:35:47.394109 0x1f5cd0f40 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20240818 21:35:47.394852 0x1f5cd0f40 incremental_mapper.cc:265] Finding good initial image pair
# I20240818 21:35:47.476475 0x1f5cd0f40 incremental_mapper.cc:289] Initializing with image pair #5 and #4
# I20240818 21:35:47.482558 0x1f5cd0f40 incremental_mapper.cc:294] Global bundle adjustment
# I20240818 21:35:48.125334 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #9 (3)
# I20240818 21:35:48.125389 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3826 / 8701 points
# I20240818 21:35:48.538777 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:35:48.798861 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #10 (4)
# I20240818 21:35:48.798872 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4910 / 9030 points
# I20240818 21:35:49.533364 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:35:49.850178 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #6 (5)
# I20240818 21:35:49.850195 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4812 / 8178 points
# I20240818 21:35:51.356531 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:35:51.704218 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #2 (6)
# I20240818 21:35:51.704236 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4990 / 8320 points
# I20240818 21:35:53.158186 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:35:53.527800 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #3 (7)
# I20240818 21:35:53.527818 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 5060 / 7680 points
# I20240818 21:35:54.576798 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:35:55.034788 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #7 (8)
# I20240818 21:35:55.034811 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3844 / 7368 points
# I20240818 21:35:56.178215 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:35:56.681632 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #11 (9)
# I20240818 21:35:56.681649 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3670 / 7631 points
# I20240818 21:35:57.770237 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:35:58.283019 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #1 (10)
# I20240818 21:35:58.283034 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4284 / 5421 points
# I20240818 21:35:59.087452 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:35:59.576137 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #8 (11)
# I20240818 21:35:59.576157 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3193 / 4963 points
# I20240818 21:36:00.244285 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:36:00.745764 0x1f5cd0f40 timer.cc:91] Elapsed time: 0.223 [minutes]
# Reconstruction completed and saved to .././Datasets/fountain/reconstruction
# Number of registered images: 11
# Number of 3D points: 14225
# Point cloud saved as PLY file: .././Datasets/fountain/reconstruction/reconstruction.ply
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display

# %%
import os
import pycolmap
import numpy as np
import open3d as o3d
import subprocess

# ... existing code ...

if reconstructions:
    reconstruction = next(iter(reconstructions.values()))
    print(f"Reconstruction completed and saved to {output_path}")
    print(f"Number of registered images: {reconstruction.num_reg_images()}")
    print(f"Number of 3D points: {reconstruction.num_points3D()}")

    # Save reconstruction as text files
    reconstruction.write_text(output_path)

    # Run dense reconstruction using COLMAP command-line
    colmap_bin = "colmap"  # Adjust this path if necessary

    # Undistort images
    subprocess.run([colmap_bin, "image_undistorter", 
                    "--image_path", dataset_path,
                    "--input_path", output_path,
                    "--output_path", os.path.join(output_path, "dense"),
                    "--output_type", "COLMAP"])

    # Run dense stereo
    subprocess.run([colmap_bin, "patch_match_stereo", 
                    "--workspace_path", os.path.join(output_path, "dense")])

    # Run stereo fusion
    subprocess.run([colmap_bin, "stereo_fusion", 
                    "--workspace_path", os.path.join(output_path, "dense"),
                    "--input_type", "geometric",
                    "--output_path", os.path.join(output_path, "dense", "fused.ply")])

    # Run Poisson surface reconstruction
    subprocess.run([colmap_bin, "poisson_mesher", 
                    "--input_path", os.path.join(output_path, "dense", "fused.ply"),
                    "--output_path", os.path.join(output_path, "dense", "meshed-poisson.ply")])

    # Run texture mapping
    subprocess.run([colmap_bin, "model_converter", 
                    "--input_path", output_path,
                    "--output_path", os.path.join(output_path, "dense", "sparse"),
                    "--output_type", "TXT"])

    subprocess.run([colmap_bin, "image_undistorter", 
                    "--image_path", dataset_path,
                    "--input_path", os.path.join(output_path, "dense", "sparse"),
                    "--output_path", os.path.join(output_path, "dense", "images"),
                    "--output_type", "COLMAP"])

    subprocess.run([colmap_bin, "texture_mapping", 
                    "--workspace_path", os.path.join(output_path, "dense", "images"),
                    "--input_path", os.path.join(output_path, "dense", "meshed-poisson.ply"),
                    "--output_path", os.path.join(output_path, "dense", "textured.obj")])

    # Load the textured mesh
    textured_mesh_path = os.path.join(output_path, "dense", "textured.obj")
    textured_mesh = o3d.io.read_triangle_mesh(textured_mesh_path)

    # Ensure the mesh has vertex colors (required for visualization)
    if not textured_mesh.has_vertex_colors():
        textured_mesh.vertex_colors = o3d.utility.Vector3dVector(np.random.uniform(0, 1, size=(len(textured_mesh.vertices), 3)))

    # Visualize the textured mesh
    o3d.visualization.draw_geometries([textured_mesh])

    print(f"Textured mesh saved as: {textured_mesh_path}")

else:
    print("No reconstruction was created.")
# Out:
# Reconstruction completed and saved to .././Datasets/fountain/reconstruction
# Number of registered images: 11
# Number of 3D points: 14225
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 22
#      19 colmap_bin = "colmap"  # Adjust this path if necessary
#      21 # Undistort images
# ---> 22 subprocess.run([colmap_bin, "image_undistorter",
#      23                 "--image_path", dataset_path,
#      24                 "--input_path", output_path,
#      25                 "--output_path", os.path.join(output_path, "dense"),
#      26                 "--output_type", "COLMAP"])
#      28 # Run dense stereo
#      29 subprocess.run([colmap_bin, "patch_match_stereo",
#      30                 "--workspace_path", os.path.join(output_path, "dense")])
#
# File /opt/anaconda3/envs/CV/lib/python3.9/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     502     kwargs['stdout'] = PIPE
#     503     kwargs['stderr'] = PIPE
# --> 505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
#     507         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /opt/anaconda3/envs/CV/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /opt/anaconda3/envs/CV/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'colmap'

# %%
import os
import pycolmap
import numpy as np
import open3d as o3d
import subprocess

# Set the path to the dataset
dataset_path = "Datasets/fountain"

# Create a COLMAP database
database_path = os.path.join(dataset_path, "database.db")
db = pycolmap.Database(database_path)

# Configure SIFT feature extraction options
sift_options = pycolmap.SiftExtractionOptions()
sift_options.max_num_features = 8192
sift_options.first_octave = -1
sift_options.num_octaves = 4

# Configure image reader options
reader_options = pycolmap.ImageReaderOptions()

# Extract features
pycolmap.extract_features(database_path, dataset_path, image_list=[],
                          camera_mode=pycolmap.CameraMode.AUTO,
                          camera_model="OPENCV",
                          reader_options=reader_options,
                          sift_options=sift_options)

# Match features
pycolmap.match_exhaustive(database_path)

# Configure incremental mapping options
pipeline_options = pycolmap.IncrementalPipelineOptions()
pipeline_options.mapper.num_threads = 4
pipeline_options.mapper.init_min_num_inliers = 100
pipeline_options.mapper.abs_pose_min_num_inliers = 30
pipeline_options.mapper.abs_pose_min_inlier_ratio = 0.25

# Set up output path
output_path = os.path.join(dataset_path, "reconstruction")
os.makedirs(output_path, exist_ok=True)

# Run incremental mapping
reconstructions = pycolmap.incremental_mapping(database_path, dataset_path, output_path, options=pipeline_options)

if reconstructions:
    reconstruction = next(iter(reconstructions.values()))
    print(f"Reconstruction completed and saved to {output_path}")
    print(f"Number of registered images: {reconstruction.num_reg_images()}")
    print(f"Number of 3D points: {reconstruction.num_points3D()}")

    # Save reconstruction as text files
    reconstruction.write_text(output_path)

    # Run dense reconstruction using COLMAP command-line
    colmap_bin = "colmap"  # Adjust this path if necessary

    # Undistort images
    subprocess.run([colmap_bin, "image_undistorter", 
                    "--image_path", dataset_path,
                    "--input_path", output_path,
                    "--output_path", os.path.join(output_path, "dense"),
                    "--output_type", "COLMAP"])

    # Run dense stereo
    subprocess.run([colmap_bin, "patch_match_stereo", 
                    "--workspace_path", os.path.join(output_path, "dense")])

    # Run stereo fusion
    subprocess.run([colmap_bin, "stereo_fusion", 
                    "--workspace_path", os.path.join(output_path, "dense"),
                    "--input_type", "geometric",
                    "--output_path", os.path.join(output_path, "dense", "fused.ply")])

    # Run Poisson surface reconstruction
    subprocess.run([colmap_bin, "poisson_mesher", 
                    "--input_path", os.path.join(output_path, "dense", "fused.ply"),
                    "--output_path", os.path.join(output_path, "dense", "meshed-poisson.ply")])

    # Run texture mapping
    subprocess.run([colmap_bin, "model_converter", 
                    "--input_path", output_path,
                    "--output_path", os.path.join(output_path, "dense", "sparse"),
                    "--output_type", "TXT"])

    subprocess.run([colmap_bin, "image_undistorter", 
                    "--image_path", dataset_path,
                    "--input_path", os.path.join(output_path, "dense", "sparse"),
                    "--output_path", os.path.join(output_path, "dense", "images"),
                    "--output_type", "COLMAP"])

    subprocess.run([colmap_bin, "texture_mapping", 
                    "--workspace_path", os.path.join(output_path, "dense", "images"),
                    "--input_path", os.path.join(output_path, "dense", "meshed-poisson.ply"),
                    "--output_path", os.path.join(output_path, "dense", "textured.obj")])

    # Load the textured mesh
    textured_mesh_path = os.path.join(output_path, "dense", "textured.obj")
    textured_mesh = o3d.io.read_triangle_mesh(textured_mesh_path)

    # Ensure the mesh has vertex colors (required for visualization)
    if not textured_mesh.has_vertex_colors():
        textured_mesh.vertex_colors = o3d.utility.Vector3dVector(np.random.uniform(0, 1, size=(len(textured_mesh.vertices), 3)))

    # Visualize the textured mesh
    o3d.visualization.draw_geometries([textured_mesh])

    print(f"Textured mesh saved as: {textured_mesh_path}")

else:
    print("No reconstruction was created.")
# Out:
# E20240818 21:28:10.211627 0x1f5cd0f40 database.cc:263] SQLite error: unable to open database file
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 12
#      10 # Create a COLMAP database
#      11 database_path = os.path.join(dataset_path, "database.db")
# ---> 12 db = pycolmap.Database(database_path)
#      14 # Configure SIFT feature extraction options
#      15 sift_options = pycolmap.SiftExtractionOptions()
#
# RuntimeError: [database.cc:263] SQLite error: unable to open database file

# %%
import os
import pycolmap
import numpy as np
import open3d as o3d
import subprocess

# Set the path to the dataset
dataset_path = "Datasets/fountain"

# Create a COLMAP database
database_path = os.path.join(dataset_path, "database.db")
db = pycolmap.Database(database_path)

# Configure SIFT feature extraction options
sift_options = pycolmap.SiftExtractionOptions()
sift_options.max_num_features = 8192
sift_options.first_octave = -1
sift_options.num_octaves = 4

# Configure image reader options
reader_options = pycolmap.ImageReaderOptions()

# Extract features
pycolmap.extract_features(database_path, dataset_path, image_list=[],
                          camera_mode=pycolmap.CameraMode.AUTO,
                          camera_model="OPENCV",
                          reader_options=reader_options,
                          sift_options=sift_options)

# Match features
pycolmap.match_exhaustive(database_path)

# Configure incremental mapping options
pipeline_options = pycolmap.IncrementalPipelineOptions()
pipeline_options.mapper.num_threads = 4
pipeline_options.mapper.init_min_num_inliers = 100
pipeline_options.mapper.abs_pose_min_num_inliers = 30
pipeline_options.mapper.abs_pose_min_inlier_ratio = 0.25

# Set up output path
output_path = os.path.join(dataset_path, "reconstruction")
os.makedirs(output_path, exist_ok=True)

# Run incremental mapping
reconstructions = pycolmap.incremental_mapping(database_path, dataset_path, output_path, options=pipeline_options)

if reconstructions:
    reconstruction = next(iter(reconstructions.values()))
    print(f"Reconstruction completed and saved to {output_path}")
    print(f"Number of registered images: {reconstruction.num_reg_images()}")
    print(f"Number of 3D points: {reconstruction.num_points3D()}")

    # Save reconstruction as text files
    reconstruction.write_text(output_path)

    # Run dense reconstruction using COLMAP command-line
    colmap_bin = "colmap"  # Adjust this path if necessary

    # Undistort images
    subprocess.run([colmap_bin, "image_undistorter", 
                    "--image_path", dataset_path,
                    "--input_path", output_path,
                    "--output_path", os.path.join(output_path, "dense"),
                    "--output_type", "COLMAP"])

    # Run dense stereo
    subprocess.run([colmap_bin, "patch_match_stereo", 
                    "--workspace_path", os.path.join(output_path, "dense")])

    # Run stereo fusion
    subprocess.run([colmap_bin, "stereo_fusion", 
                    "--workspace_path", os.path.join(output_path, "dense"),
                    "--input_type", "geometric",
                    "--output_path", os.path.join(output_path, "dense", "fused.ply")])

    # Run Poisson surface reconstruction
    subprocess.run([colmap_bin, "poisson_mesher", 
                    "--input_path", os.path.join(output_path, "dense", "fused.ply"),
                    "--output_path", os.path.join(output_path, "dense", "meshed-poisson.ply")])

    # Run texture mapping
    subprocess.run([colmap_bin, "model_converter", 
                    "--input_path", output_path,
                    "--output_path", os.path.join(output_path, "dense", "sparse"),
                    "--output_type", "TXT"])

    subprocess.run([colmap_bin, "image_undistorter", 
                    "--image_path", dataset_path,
                    "--input_path", os.path.join(output_path, "dense", "sparse"),
                    "--output_path", os.path.join(output_path, "dense", "images"),
                    "--output_type", "COLMAP"])

    subprocess.run([colmap_bin, "texture_mapping", 
                    "--workspace_path", os.path.join(output_path, "dense", "images"),
                    "--input_path", os.path.join(output_path, "dense", "meshed-poisson.ply"),
                    "--output_path", os.path.join(output_path, "dense", "textured.obj")])

    # Load the textured mesh
    textured_mesh_path = os.path.join(output_path, "dense", "textured.obj")
    textured_mesh = o3d.io.read_triangle_mesh(textured_mesh_path)

    # Ensure the mesh has vertex colors (required for visualization)
    if not textured_mesh.has_vertex_colors():
        textured_mesh.vertex_colors = o3d.utility.Vector3dVector(np.random.uniform(0, 1, size=(len(textured_mesh.vertices), 3)))

    # Visualize the textured mesh
    o3d.visualization.draw_geometries([textured_mesh])

    print(f"Textured mesh saved as: {textured_mesh_path}")

else:
    print("No reconstruction was created.")
# Out:
# E20240818 21:28:21.804961 0x1f5cd0f40 database.cc:263] SQLite error: unable to open database file
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 12
#      10 # Create a COLMAP database
#      11 database_path = os.path.join(dataset_path, "database.db")
# ---> 12 db = pycolmap.Database(database_path)
#      14 # Configure SIFT feature extraction options
#      15 sift_options = pycolmap.SiftExtractionOptions()
#
# RuntimeError: [database.cc:263] SQLite error: unable to open database file

# %%
import os
import pycolmap
import numpy as np
import open3d as o3d
import subprocess

# Set the path to the dataset
dataset_path = "Datasets/fountain"

# Create a COLMAP database
database_path = os.path.join(dataset_path, "database.db")
db = pycolmap.Database(database_path)

# Configure SIFT feature extraction options
sift_options = pycolmap.SiftExtractionOptions()
sift_options.max_num_features = 8192
sift_options.first_octave = -1
sift_options.num_octaves = 4

# Configure image reader options
reader_options = pycolmap.ImageReaderOptions()

# Extract features
pycolmap.extract_features(database_path, dataset_path, image_list=[],
                          camera_mode=pycolmap.CameraMode.AUTO,
                          camera_model="OPENCV",
                          reader_options=reader_options,
                          sift_options=sift_options)

# Match features
pycolmap.match_exhaustive(database_path)

# Configure incremental mapping options
pipeline_options = pycolmap.IncrementalPipelineOptions()
pipeline_options.mapper.num_threads = 4
pipeline_options.mapper.init_min_num_inliers = 100
pipeline_options.mapper.abs_pose_min_num_inliers = 30
pipeline_options.mapper.abs_pose_min_inlier_ratio = 0.25

# Set up output path
output_path = os.path.join(dataset_path, "reconstruction")
os.makedirs(output_path, exist_ok=True)

# Run incremental mapping
reconstructions = pycolmap.incremental_mapping(database_path, dataset_path, output_path, options=pipeline_options)

if reconstructions:
    reconstruction = next(iter(reconstructions.values()))
    print(f"Reconstruction completed and saved to {output_path}")
    print(f"Number of registered images: {reconstruction.num_reg_images()}")
    print(f"Number of 3D points: {reconstruction.num_points3D()}")

    # Save reconstruction as text files
    reconstruction.write_text(output_path)

    # Run dense reconstruction using COLMAP command-line
    colmap_bin = "colmap"  # Adjust this path if necessary

    # Undistort images
    subprocess.run([colmap_bin, "image_undistorter", 
                    "--image_path", dataset_path,
                    "--input_path", output_path,
                    "--output_path", os.path.join(output_path, "dense"),
                    "--output_type", "COLMAP"])

    # Run dense stereo
    subprocess.run([colmap_bin, "patch_match_stereo", 
                    "--workspace_path", os.path.join(output_path, "dense")])

    # Run stereo fusion
    subprocess.run([colmap_bin, "stereo_fusion", 
                    "--workspace_path", os.path.join(output_path, "dense"),
                    "--input_type", "geometric",
                    "--output_path", os.path.join(output_path, "dense", "fused.ply")])

    # Run Poisson surface reconstruction
    subprocess.run([colmap_bin, "poisson_mesher", 
                    "--input_path", os.path.join(output_path, "dense", "fused.ply"),
                    "--output_path", os.path.join(output_path, "dense", "meshed-poisson.ply")])

    # Run texture mapping
    subprocess.run([colmap_bin, "model_converter", 
                    "--input_path", output_path,
                    "--output_path", os.path.join(output_path, "dense", "sparse"),
                    "--output_type", "TXT"])

    subprocess.run([colmap_bin, "image_undistorter", 
                    "--image_path", dataset_path,
                    "--input_path", os.path.join(output_path, "dense", "sparse"),
                    "--output_path", os.path.join(output_path, "dense", "images"),
                    "--output_type", "COLMAP"])

    subprocess.run([colmap_bin, "texture_mapping", 
                    "--workspace_path", os.path.join(output_path, "dense", "images"),
                    "--input_path", os.path.join(output_path, "dense", "meshed-poisson.ply"),
                    "--output_path", os.path.join(output_path, "dense", "textured.obj")])

    # Load the textured mesh
    textured_mesh_path = os.path.join(output_path, "dense", "textured.obj")
    textured_mesh = o3d.io.read_triangle_mesh(textured_mesh_path)

    # Ensure the mesh has vertex colors (required for visualization)
    if not textured_mesh.has_vertex_colors():
        textured_mesh.vertex_colors = o3d.utility.Vector3dVector(np.random.uniform(0, 1, size=(len(textured_mesh.vertices), 3)))

    # Visualize the textured mesh
    o3d.visualization.draw_geometries([textured_mesh])

    print(f"Textured mesh saved as: {textured_mesh_path}")

else:
    print("No reconstruction was created.")
# Out:
# W20240818 00:06:57.918786 0x1f5cd0f40 feature_extraction.cc:406] Your current options use the maximum number of threads on the machine to extract features. Extracting SIFT features on the CPU can consume a lot of RAM per thread for large images. Consider reducing the maximum image size and/or the first octave or manually limit the number of extraction threads. Ignore this warning, if your machine has sufficient memory for the current settings.
# I20240818 00:06:57.918880 0x33e6bb000 misc.cc:198]
# ==============================================================================
# Feature extraction
# ==============================================================================
# I20240818 00:06:57.919052 0x365fa3000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919071 0x3660bb000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919069 0x36602f000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919095 0x3661d3000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919099 0x36625f000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919109 0x3662eb000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919150 0x36651b000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919109 0x366147000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919162 0x3665a7000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919123 0x366377000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919153 0x36648f000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919153 0x366403000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 00:06:57.919503 0x366633000 feature_extraction.cc:257] Processed file [1/42]
# I20240818 00:06:57.919513 0x366633000 feature_extraction.cc:260]   Name:            .DS_Store
# E20240818 00:06:57.919517 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.919547 0x366633000 feature_extraction.cc:257] Processed file [2/42]
# I20240818 00:06:57.919550 0x366633000 feature_extraction.cc:260]   Name:            0001.png
# I20240818 00:06:57.919553 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.919881 0x366633000 feature_extraction.cc:257] Processed file [3/42]
# I20240818 00:06:57.919888 0x366633000 feature_extraction.cc:260]   Name:            0001.png.camera
# E20240818 00:06:57.919893 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.919991 0x366633000 feature_extraction.cc:257] Processed file [4/42]
# I20240818 00:06:57.919999 0x366633000 feature_extraction.cc:260]   Name:            00010.png.camera
# E20240818 00:06:57.920004 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.920156 0x366633000 feature_extraction.cc:257] Processed file [5/42]
# I20240818 00:06:57.920161 0x366633000 feature_extraction.cc:260]   Name:            00011.png.camera
# E20240818 00:06:57.920163 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.920177 0x366633000 feature_extraction.cc:257] Processed file [6/42]
# I20240818 00:06:57.920181 0x366633000 feature_extraction.cc:260]   Name:            0002.png
# I20240818 00:06:57.920184 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.920282 0x366633000 feature_extraction.cc:257] Processed file [7/42]
# I20240818 00:06:57.920288 0x366633000 feature_extraction.cc:260]   Name:            0002.png.camera
# E20240818 00:06:57.920292 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.920309 0x366633000 feature_extraction.cc:257] Processed file [8/42]
# I20240818 00:06:57.920313 0x366633000 feature_extraction.cc:260]   Name:            0003.png
# I20240818 00:06:57.920315 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.920445 0x366633000 feature_extraction.cc:257] Processed file [9/42]
# I20240818 00:06:57.920452 0x366633000 feature_extraction.cc:260]   Name:            0003.png.camera
# E20240818 00:06:57.920455 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.920478 0x366633000 feature_extraction.cc:257] Processed file [10/42]
# I20240818 00:06:57.920481 0x366633000 feature_extraction.cc:260]   Name:            0004.png
# I20240818 00:06:57.920483 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.920565 0x366633000 feature_extraction.cc:257] Processed file [11/42]
# I20240818 00:06:57.920571 0x366633000 feature_extraction.cc:260]   Name:            0004.png.camera
# E20240818 00:06:57.920573 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.920586 0x366633000 feature_extraction.cc:257] Processed file [12/42]
# I20240818 00:06:57.920588 0x366633000 feature_extraction.cc:260]   Name:            0005.png
# I20240818 00:06:57.920590 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.920726 0x366633000 feature_extraction.cc:257] Processed file [13/42]
# I20240818 00:06:57.920730 0x366633000 feature_extraction.cc:260]   Name:            0005.png.camera
# E20240818 00:06:57.920733 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.920745 0x366633000 feature_extraction.cc:257] Processed file [14/42]
# I20240818 00:06:57.920747 0x366633000 feature_extraction.cc:260]   Name:            0006.png
# I20240818 00:06:57.920750 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.920841 0x366633000 feature_extraction.cc:257] Processed file [15/42]
# I20240818 00:06:57.920845 0x366633000 feature_extraction.cc:260]   Name:            0006.png.camera
# E20240818 00:06:57.920847 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.920863 0x366633000 feature_extraction.cc:257] Processed file [16/42]
# I20240818 00:06:57.920865 0x366633000 feature_extraction.cc:260]   Name:            0007.png
# I20240818 00:06:57.920868 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.921326 0x366633000 feature_extraction.cc:257] Processed file [17/42]
# I20240818 00:06:57.921333 0x366633000 feature_extraction.cc:260]   Name:            0007.png.camera
# E20240818 00:06:57.921335 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.921349 0x366633000 feature_extraction.cc:257] Processed file [18/42]
# I20240818 00:06:57.921352 0x366633000 feature_extraction.cc:260]   Name:            0008.png
# I20240818 00:06:57.921354 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.921559 0x366633000 feature_extraction.cc:257] Processed file [19/42]
# I20240818 00:06:57.921569 0x366633000 feature_extraction.cc:260]   Name:            0008.png.camera
# E20240818 00:06:57.921574 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.921614 0x366633000 feature_extraction.cc:257] Processed file [20/42]
# I20240818 00:06:57.921620 0x366633000 feature_extraction.cc:260]   Name:            0009.png
# I20240818 00:06:57.921623 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.921794 0x366633000 feature_extraction.cc:257] Processed file [21/42]
# I20240818 00:06:57.921800 0x366633000 feature_extraction.cc:260]   Name:            0009.png.camera
# E20240818 00:06:57.921803 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.921818 0x366633000 feature_extraction.cc:257] Processed file [22/42]
# I20240818 00:06:57.921821 0x366633000 feature_extraction.cc:260]   Name:            0010.png
# I20240818 00:06:57.921824 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.921832 0x366633000 feature_extraction.cc:257] Processed file [23/42]
# I20240818 00:06:57.921835 0x366633000 feature_extraction.cc:260]   Name:            0011.png
# I20240818 00:06:57.921838 0x366633000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 00:06:57.921985 0x366633000 feature_extraction.cc:257] Processed file [24/42]
# I20240818 00:06:57.922021 0x366633000 feature_extraction.cc:260]   Name:            database.db
# E20240818 00:06:57.922026 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.922128 0x366633000 feature_extraction.cc:257] Processed file [25/42]
# I20240818 00:06:57.922134 0x366633000 feature_extraction.cc:260]   Name:            database.db-shm
# E20240818 00:06:57.922137 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.922212 0x366633000 feature_extraction.cc:257] Processed file [26/42]
# I20240818 00:06:57.922216 0x366633000 feature_extraction.cc:260]   Name:            database.db-wal
# E20240818 00:06:57.922219 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.922403 0x366633000 feature_extraction.cc:257] Processed file [27/42]
# I20240818 00:06:57.922409 0x366633000 feature_extraction.cc:260]   Name:            reconstruction/.DS_Store
# E20240818 00:06:57.922412 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.922522 0x366633000 feature_extraction.cc:257] Processed file [28/42]
# I20240818 00:06:57.922529 0x366633000 feature_extraction.cc:260]   Name:            reconstruction/0/cameras.bin
# E20240818 00:06:57.922532 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.922670 0x366633000 feature_extraction.cc:257] Processed file [29/42]
# I20240818 00:06:57.922676 0x366633000 feature_extraction.cc:260]   Name:            reconstruction/0/images.bin
# E20240818 00:06:57.922679 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.922770 0x366633000 feature_extraction.cc:257] Processed file [30/42]
# I20240818 00:06:57.922779 0x366633000 feature_extraction.cc:260]   Name:            reconstruction/0/points3D.bin
# E20240818 00:06:57.922783 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.922941 0x366633000 feature_extraction.cc:257] Processed file [31/42]
# I20240818 00:06:57.922947 0x366633000 feature_extraction.cc:260]   Name:            reconstruction/cameras.txt
# E20240818 00:06:57.922950 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.923218 0x366633000 feature_extraction.cc:257] Processed file [32/42]
# I20240818 00:06:57.923223 0x366633000 feature_extraction.cc:260]   Name:            reconstruction/images.txt
# E20240818 00:06:57.923225 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.923393 0x366633000 feature_extraction.cc:257] Processed file [33/42]
# I20240818 00:06:57.923411 0x366633000 feature_extraction.cc:260]   Name:            reconstruction/points3D.txt
# E20240818 00:06:57.923418 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.923521 0x366633000 feature_extraction.cc:257] Processed file [34/42]
# I20240818 00:06:57.923544 0x366633000 feature_extraction.cc:260]   Name:            reconstruction/reconstruction.ply
# E20240818 00:06:57.923549 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.923668 0x366633000 feature_extraction.cc:257] Processed file [35/42]
# I20240818 00:06:57.923674 0x366633000 feature_extraction.cc:260]   Name:            reconstruction/textured_reconstruction.obj
# E20240818 00:06:57.923677 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.923776 0x366633000 feature_extraction.cc:257] Processed file [36/42]
# I20240818 00:06:57.923781 0x366633000 feature_extraction.cc:260]   Name:            run-colmap-geometric.sh
# E20240818 00:06:57.923784 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.923965 0x366633000 feature_extraction.cc:257] Processed file [37/42]
# I20240818 00:06:57.923972 0x366633000 feature_extraction.cc:260]   Name:            run-colmap-photometric.sh
# E20240818 00:06:57.923976 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.924029 0x366633000 feature_extraction.cc:257] Processed file [38/42]
# I20240818 00:06:57.924036 0x366633000 feature_extraction.cc:260]   Name:            sparse/cameras.bin
# E20240818 00:06:57.924040 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.924182 0x366633000 feature_extraction.cc:257] Processed file [39/42]
# I20240818 00:06:57.924187 0x366633000 feature_extraction.cc:260]   Name:            sparse/images.bin
# E20240818 00:06:57.924190 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.924314 0x366633000 feature_extraction.cc:257] Processed file [40/42]
# I20240818 00:06:57.924320 0x366633000 feature_extraction.cc:260]   Name:            sparse/points3D.bin
# E20240818 00:06:57.924323 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.924716 0x366633000 feature_extraction.cc:257] Processed file [41/42]
# I20240818 00:06:57.924722 0x366633000 feature_extraction.cc:260]   Name:            stereo/fusion.cfg
# E20240818 00:06:57.924729 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.924840 0x366633000 feature_extraction.cc:257] Processed file [42/42]
# I20240818 00:06:57.924857 0x366633000 feature_extraction.cc:260]   Name:            stereo/patch-match.cfg
# E20240818 00:06:57.924863 0x366633000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 00:06:57.925348 0x33e6bb000 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20240818 00:06:57.926138 0x33e6bb000 misc.cc:198]
# ==============================================================================
# Feature matching
# ==============================================================================
# I20240818 00:06:57.926246 0x3639e7000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926265 0x363a73000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926301 0x363b8b000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926300 0x363c17000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926312 0x363aff000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926339 0x365dff000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926343 0x365e8b000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926382 0x365ce7000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926305 0x363ca3000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926425 0x365f17000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926396 0x363e87000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926402 0x365d73000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 00:06:57.926530 0x33e6bb000 pairing.cc:168] Generating exhaustive image pairs...
# I20240818 00:06:57.926536 0x33e6bb000 pairing.cc:202] Matching block [1/1, 1/1]
# I20240818 00:06:57.926688 0x33e6bb000 feature_matching.cc:46]  in 0.000s
# I20240818 00:06:57.926697 0x33e6bb000 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20240818 00:06:57.927652 0x1f5cd0f40 incremental_mapper.cc:225] Loading database
# I20240818 00:06:57.928046 0x1f5cd0f40 database_cache.cc:65] Loading cameras...
# I20240818 00:06:57.928065 0x1f5cd0f40 database_cache.cc:75]  11 in 0.000s
# I20240818 00:06:57.928069 0x1f5cd0f40 database_cache.cc:83] Loading matches...
# I20240818 00:06:57.928530 0x1f5cd0f40 database_cache.cc:89]  55 in 0.000s
# I20240818 00:06:57.928537 0x1f5cd0f40 database_cache.cc:105] Loading images...
# I20240818 00:06:57.930860 0x1f5cd0f40 database_cache.cc:155]  11 in 0.002s (connected 11)
# I20240818 00:06:57.930867 0x1f5cd0f40 database_cache.cc:166] Building correspondence graph...
# I20240818 00:06:57.946165 0x1f5cd0f40 database_cache.cc:195]  in 0.015s (ignored 0)
# I20240818 00:06:57.946196 0x1f5cd0f40 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20240818 00:06:57.947359 0x1f5cd0f40 incremental_mapper.cc:265] Finding good initial image pair
# I20240818 00:06:58.026964 0x1f5cd0f40 incremental_mapper.cc:289] Initializing with image pair #5 and #4
# I20240818 00:06:58.032779 0x1f5cd0f40 incremental_mapper.cc:294] Global bundle adjustment
# I20240818 00:06:58.692786 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #9 (3)
# I20240818 00:06:58.692841 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3826 / 8701 points
# I20240818 00:06:59.115161 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 00:06:59.384678 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #10 (4)
# I20240818 00:06:59.384694 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4910 / 9030 points
# I20240818 00:07:00.184649 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 00:07:00.545995 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #6 (5)
# I20240818 00:07:00.546013 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4812 / 8178 points
# I20240818 00:07:01.836220 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 00:07:02.163526 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #2 (6)
# I20240818 00:07:02.163545 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4990 / 8320 points
# I20240818 00:07:03.583338 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 00:07:03.957510 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #3 (7)
# I20240818 00:07:03.957529 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 5060 / 7680 points
# I20240818 00:07:04.997588 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 00:07:05.443946 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #7 (8)
# I20240818 00:07:05.443961 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3844 / 7368 points
# I20240818 00:07:06.574219 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 00:07:07.063746 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #11 (9)
# I20240818 00:07:07.063761 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3670 / 7631 points
# I20240818 00:07:08.188731 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 00:07:08.759320 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #1 (10)
# I20240818 00:07:08.759339 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4284 / 5421 points
# I20240818 00:07:09.559116 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 00:07:10.043183 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #8 (11)
# I20240818 00:07:10.043198 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3193 / 4963 points
# I20240818 00:07:10.696550 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 00:07:11.233654 0x1f5cd0f40 timer.cc:91] Elapsed time: 0.222 [minutes]
# Reconstruction completed and saved to Datasets/fountain/reconstruction
# Number of registered images: 11
# Number of 3D points: 14225
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 60
#      57 colmap_bin = "colmap"  # Adjust this path if necessary
#      59 # Undistort images
# ---> 60 subprocess.run([colmap_bin, "image_undistorter",
#      61                 "--image_path", dataset_path,
#      62                 "--input_path", output_path,
#      63                 "--output_path", os.path.join(output_path, "dense"),
#      64                 "--output_type", "COLMAP"])
#      66 # Run dense stereo
#      67 subprocess.run([colmap_bin, "patch_match_stereo",
#      68                 "--workspace_path", os.path.join(output_path, "dense")])
#
# File /opt/anaconda3/envs/CV/lib/python3.9/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     502     kwargs['stdout'] = PIPE
#     503     kwargs['stderr'] = PIPE
# --> 505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
#     507         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /opt/anaconda3/envs/CV/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /opt/anaconda3/envs/CV/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'colmap'

# %%
import os
import pycolmap
import numpy as np
import open3d as o3d

# Set the path to the dataset
dataset_path = ".././Datasets/fountain"

# Create a COLMAP database
database_path = os.path.join(dataset_path, "database.db")
db = pycolmap.Database(database_path)

# Configure SIFT feature extraction options
sift_options = pycolmap.SiftExtractionOptions()
sift_options.max_num_features = 8192
sift_options.first_octave = -1
sift_options.num_octaves = 4

# Configure image reader options
reader_options = pycolmap.ImageReaderOptions()

# Extract features
pycolmap.extract_features(database_path, dataset_path, image_list=[],
                          camera_mode=pycolmap.CameraMode.AUTO,
                          camera_model="OPENCV",
                          reader_options=reader_options,
                          sift_options=sift_options)

# Match features
pycolmap.match_exhaustive(database_path)

# Configure incremental mapping options
pipeline_options = pycolmap.IncrementalPipelineOptions()
pipeline_options.mapper.num_threads = 4
pipeline_options.mapper.init_min_num_inliers = 100
pipeline_options.mapper.abs_pose_min_num_inliers = 30
pipeline_options.mapper.abs_pose_min_inlier_ratio = 0.25

# Set up output path
output_path = os.path.join(dataset_path, "reconstruction")
os.makedirs(output_path, exist_ok=True)

# Run incremental mapping
reconstructions = pycolmap.incremental_mapping(database_path, dataset_path, output_path, options=pipeline_options)

if reconstructions:
    reconstruction = next(iter(reconstructions.values()))
    print(f"Reconstruction completed and saved to {output_path}")
    print(f"Number of registered images: {reconstruction.num_reg_images()}")
    print(f"Number of 3D points: {reconstruction.num_points3D()}")

    # Save reconstruction as text files
    reconstruction.write_text(output_path)

    # Prepare point cloud data
    points = []
    colors = []

    for point3D_id in reconstruction.points3D:
        point3D = reconstruction.points3D[point3D_id]
        points.append(point3D.xyz)
        colors.append(point3D.color)

    points = np.array(points)
    colors = np.array(colors)

    # Create Open3D point cloud
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(points)
    pcd.colors = o3d.utility.Vector3dVector(colors / 255.0)

    # Post-processing: downsampling and outlier removal
    pcd = pcd.voxel_down_sample(voxel_size=0.01)
    pcd, _ = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)

    # Create mesh from point cloud
    mesh, _ = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(pcd, depth=9)

    # Simplify mesh
    mesh = mesh.simplify_quadric_decimation(target_number_of_triangles=100000)

    # Estimate vertex normals for better visualization
    mesh.compute_vertex_normals()

    # Save mesh as OBJ file
    mesh_path = os.path.join(output_path, "reconstructed_mesh.obj")
    o3d.io.write_triangle_mesh(mesh_path, mesh)
    print(f"Mesh saved as: {mesh_path}")

    # Visualize the mesh
    o3d.visualization.draw_geometries([mesh])

else:
    print("No reconstruction was created.")
# Out:
# W20240818 21:29:47.603452 0x1f5cd0f40 feature_extraction.cc:406] Your current options use the maximum number of threads on the machine to extract features. Extracting SIFT features on the CPU can consume a lot of RAM per thread for large images. Consider reducing the maximum image size and/or the first octave or manually limit the number of extraction threads. Ignore this warning, if your machine has sufficient memory for the current settings.
# I20240818 21:29:47.603711 0x3108eb000 misc.cc:198]
# ==============================================================================
# Feature extraction
# ==============================================================================
# I20240818 21:29:47.603932 0x332c43000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.603940 0x332ccf000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.604084 0x332d5b000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.604206 0x334de7000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.604251 0x33ee73000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.604456 0x344187000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.604485 0x3625c3000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.604527 0x3636fb000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.604594 0x364627000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.604652 0x3646b3000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.604681 0x36473f000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.604682 0x3647cb000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:29:47.605332 0x364857000 feature_extraction.cc:257] Processed file [1/42]
# I20240818 21:29:47.605338 0x364857000 feature_extraction.cc:260]   Name:            .DS_Store
# E20240818 21:29:47.605341 0x364857000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:29:47.605501 0x364857000 feature_extraction.cc:257] Processed file [2/42]
# I20240818 21:29:47.605508 0x364857000 feature_extraction.cc:260]   Name:            0001.png
# I20240818 21:29:47.605511 0x364857000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21
# I20240818 21:29:47.627416 0x1f5cd0f40 database_cache.cc:166] Building correspondence graph...
# I20240818 21:29:47.641133 0x1f5cd0f40 database_cache.cc:195]  in 0.014s (ignored 0)
# I20240818 21:29:47.641148 0x1f5cd0f40 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20240818 21:29:47.642100 0x1f5cd0f40 incremental_mapper.cc:265] Finding good initial image pair
# I20240818 21:29:47.726585 0x1f5cd0f40 incremental_mapper.cc:289] Initializing with image pair #5 and #4
# I20240818 21:29:47.732679 0x1f5cd0f40 incremental_mapper.cc:294] Global bundle adjustment
# I20240818 21:29:48.420099 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #9 (3)
# I20240818 21:29:48.420117 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3826 / 8701 points
# I20240818 21:29:48.872105 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:29:49.153606 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #10 (4)
# I20240818 21:29:49.153619 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4910 / 9030 points
# I20240818 21:29:49.971458 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:29:50.322693 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #6 (5)
# I20240818 21:29:50.322709 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4812 / 8178 points
# I20240818 21:29:51.591254 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:29:51.919251 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #2 (6)
# I20240818 21:29:51.919267 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4990 / 8320 points
# I20240818 21:29:53.359170 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:29:53.745402 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #3 (7)
# I20240818 21:29:53.745418 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 5060 / 7680 points
# I20240818 21:29:54.790827 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:29:55.248996 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #7 (8)
# I20240818 21:29:55.249010 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3844 / 7368 points
# I20240818 21:29:56.398811 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:29:56.895038 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #11 (9)
# I20240818 21:29:56.895055 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3670 / 7631 points
# I20240818 21:29:57.995655 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:29:58.531684 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #1 (10)
# I20240818 21:29:58.531706 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 4284 / 5421 points
# I20240818 21:29:59.390154 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:29:59.952942 0x1f5cd0f40 incremental_mapper.cc:375] Registering image #8 (11)
# I20240818 21:29:59.952958 0x1f5cd0f40 incremental_mapper.cc:378] => Image sees 3193 / 4963 points
# I20240818 21:30:00.662336 0x1f5cd0f40 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20240818 21:30:01.183682 0x1f5cd0f40 timer.cc:91] Elapsed time: 0.226 [minutes]
# Reconstruction completed and saved to .././Datasets/fountain/reconstruction
# Number of registered images: 11
# Number of 3D points: 14225
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 77
#      74 pcd, _ = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)
#      76 # Create mesh from point cloud
# ---> 77 mesh, _ = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(pcd, depth=9)
#      79 # Simplify mesh
#      80 mesh = mesh.simplify_quadric_decimation(target_number_of_triangles=100000)
#
# RuntimeError: [Open3D Error] (static std::tuple<std::shared_ptr<TriangleMesh>, std::vector<double>> open3d::geometry::TriangleMesh::CreateFromPointCloudPoisson(const PointCloud &, size_t, float, float, bool, int)) /Users/renes/development/open3d_work/Open3D/cpp/open3d/geometry/SurfaceReconstructionPoisson.cpp:732: Point cloud has no normals

# %%
import os
import pycolmap
import numpy as np
import open3d as o3d

# Set the path to the dataset
dataset_path = ".././Datasets/fountain"

# Create a COLMAP database
database_path = os.path.join(dataset_path, "database.db")
db = pycolmap.Database(database_path)

# Configure SIFT feature extraction options
sift_options = pycolmap.SiftExtractionOptions()
sift_options.max_num_features = 8192
sift_options.first_octave = -1
sift_options.num_octaves = 4

# Configure image reader options
reader_options = pycolmap.ImageReaderOptions()

# Extract features
pycolmap.extract_features(database_path, dataset_path, image_list=[],
                          camera_mode=pycolmap.CameraMode.AUTO,
                          camera_model="OPENCV",
                          reader_options=reader_options,
                          sift_options=sift_options)

# Match features
pycolmap.match_exhaustive(database_path)

# Configure incremental mapping options
pipeline_options = pycolmap.IncrementalPipelineOptions()
pipeline_options.mapper.num_threads = 4
pipeline_options.mapper.init_min_num_inliers = 100
pipeline_options.mapper.abs_pose_min_num_inliers = 30
pipeline_options.mapper.abs_pose_min_inlier_ratio = 0.25

# Set up output path
output_path = os.path.join(dataset_path, "reconstruction")
os.makedirs(output_path, exist_ok=True)

# Run incremental mapping
reconstructions = pycolmap.incremental_mapping(database_path, dataset_path, output_path, options=pipeline_options)

if reconstructions:
    reconstruction = next(iter(reconstructions.values()))
    print(f"Reconstruction completed and saved to {output_path}")
    print(f"Number of registered images: {reconstruction.num_reg_images()}")
    print(f"Number of 3D points: {reconstruction.num_points3D()}")

    # Save reconstruction as text files
    reconstruction.write_text(output_path)

    # Prepare point cloud data
    points = []
    colors = []

    for point3D_id in reconstruction.points3D:
        point3D = reconstruction.points3D[point3D_id]
        points.append(point3D.xyz)
        colors.append(point3D.color)

    points = np.array(points)
    colors = np.array(colors)

    # Create Open3D point cloud
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(points)
    pcd.colors = o3d.utility.Vector3dVector(colors / 255.0)

    # Post-processing: downsampling and outlier removal
    pcd = pcd.voxel_down_sample(voxel_size=0.01)
    pcd, _ = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)

    # Estimate normals
    pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
    pcd.orient_normals_consistent_tangent_plane(100)

    # Visualize the point cloud (optional, for debugging)
    # o3d.visualization.draw_geometries([pcd])

    # Create mesh from point cloud
    print("Creating mesh from point cloud...")
    mesh, _ = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(pcd, depth=9)

    # Remove low-density vertices
    print("Removing low-density vertices...")
    vertices_to_remove = mesh.remove_vertices_by_mask(mesh.vertex_density() < 0.01)
    print(f"Removed {vertices_to_remove} low-density vertices")

    # Simplify mesh
    print("Simplifying mesh...")
    mesh = mesh.simplify_quadric_decimation(target_number_of_triangles=100000)

    # Estimate vertex normals for better visualization
    mesh.compute_vertex_normals()

    # Save mesh as OBJ file
    mesh_path = os.path.join(output_path, "reconstructed_mesh.obj")
    o3d.io.write_triangle_mesh(mesh_path, mesh)
    print(f"Mesh saved as: {mesh_path}")

    # Visualize the mesh
    print("Visualizing the mesh...")
    o3d.visualization.draw_geometries([mesh])

else:
    print("No reconstruction was created.")
# Out:
# W20240818 21:34:44.066395 0x1f5cd0f40 feature_extraction.cc:406] Your current options use the maximum number of threads on the machine to extract features. Extracting SIFT features on the CPU can consume a lot of RAM per thread for large images. Consider reducing the maximum image size and/or the first octave or manually limit the number of extraction threads. Ignore this warning, if your machine has sufficient memory for the current settings.
# I20240818 21:34:44.066513 0x3108eb000 misc.cc:198]
# ==============================================================================
# Feature extraction
# ==============================================================================
# I20240818 21:34:44.066778 0x3625c3000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:34:44.066778 0x3636fb000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:34:44.066872 0x364b87000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:34:44.066878 0x364c13000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:34:44.066857 0x36499f000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:34:44.066897 0x364d2b000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:34:44.066872 0x364913000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:34:44.066811 0x364627000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:34:44.066916 0x364db7000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:34:44.066874 0x364887000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21:34:44.066914 0x364c9f000 sift.cc:722] Creating SIFT CPU feature extractor
# I20240818 21
 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21:34:44.072245 0x364e43000 feature_extraction.cc:257] Processed file [17/42]
# I20240818 21:34:44.072252 0x364e43000 feature_extraction.cc:260]   Name:            0007.png.camera
# E20240818 21:34:44.072257 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.072419 0x364e43000 feature_extraction.cc:257] Processed file [18/42]
# I20240818 21:34:44.072425 0x364e43000 feature_extraction.cc:260]   Name:            0008.png
# I20240818 21:34:44.072429 0x364e43000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21:34:44.072580 0x364e43000 feature_extraction.cc:257] Processed file [19/42]
# I20240818 21:34:44.072587 0x364e43000 feature_extraction.cc:260]   Name:            0008.png.camera
# E20240818 21:34:44.072591 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.072617 0x364e43000 feature_extraction.cc:257] Processed file [20/42]
# I20240818 21:34:44.072620 0x364e43000 feature_extraction.cc:260]   Name:            0009.png
# I20240818 21:34:44.072634 0x364e43000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21:34:44.072757 0x364e43000 feature_extraction.cc:257] Processed file [21/42]
# I20240818 21:34:44.072765 0x364e43000 feature_extraction.cc:260]   Name:            0009.png.camera
# E20240818 21:34:44.072768 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.072787 0x364e43000 feature_extraction.cc:257] Processed file [22/42]
# I20240818 21:34:44.072792 0x364e43000 feature_extraction.cc:260]   Name:            0010.png
# I20240818 21:34:44.072795 0x364e43000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21:34:44.072798 0x364e43000 feature_extraction.cc:257] Processed file [23/42]
# I20240818 21:34:44.072821 0x364e43000 feature_extraction.cc:260]   Name:            0011.png
# I20240818 21:34:44.072826 0x364e43000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20240818 21:34:44.072957 0x364e43000 feature_extraction.cc:257] Processed file [24/42]
# I20240818 21:34:44.072963 0x364e43000 feature_extraction.cc:260]   Name:            database.db
# E20240818 21:34:44.072967 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.073071 0x364e43000 feature_extraction.cc:257] Processed file [25/42]
# I20240818 21:34:44.073077 0x364e43000 feature_extraction.cc:260]   Name:            database.db-shm
# E20240818 21:34:44.073080 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.073222 0x364e43000 feature_extraction.cc:257] Processed file [26/42]
# I20240818 21:34:44.073229 0x364e43000 feature_extraction.cc:260]   Name:            database.db-wal
# E20240818 21:34:44.073234 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.073369 0x364e43000 feature_extraction.cc:257] Processed file [27/42]
# I20240818 21:34:44.073374 0x364e43000 feature_extraction.cc:260]   Name:            reconstruction/.DS_Store
# E20240818 21:34:44.073378 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.073634 0x364e43000 feature_extraction.cc:257] Processed file [28/42]
# I20240818 21:34:44.073644 0x364e43000 feature_extraction.cc:260]   Name:            reconstruction/0/cameras.bin
# E20240818 21:34:44.073648 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.074035 0x364e43000 feature_extraction.cc:257] Processed file [29/42]
# I20240818 21:34:44.074040 0x364e43000 feature_extraction.cc:260]   Name:            reconstruction/0/images.bin
# E20240818 21:34:44.074043 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.074448 0x364e43000 feature_extraction.cc:257] Processed file [30/42]
# I20240818 21:34:44.074455 0x364e43000 feature_extraction.cc:260]   Name:            reconstruction/0/points3D.bin
# E20240818 21:34:44.074459 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.074723 0x364e43000 feature_extraction.cc:257] Processed file [31/42]
# I20240818 21:34:44.074730 0x364e43000 feature_extraction.cc:260]   Name:            reconstruction/cameras.txt
# E20240818 21:34:44.074733 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.075195 0x364e43000 feature_extraction.cc:257] Processed file [32/42]
# I20240818 21:34:44.075204 0x364e43000 feature_extraction.cc:260]   Name:            reconstruction/images.txt
# E20240818 21:34:44.075209 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.075614 0x364e43000 feature_extraction.cc:257] Processed file [33/42]
# I20240818 21:34:44.075620 0x364e43000 feature_extraction.cc:260]   Name:            reconstruction/points3D.txt
# E20240818 21:34:44.075624 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.076059 0x364e43000 feature_extraction.cc:257] Processed file [34/42]
# I20240818 21:34:44.076065 0x364e43000 feature_extraction.cc:260]   Name:            reconstruction/reconstruction.ply
# E20240818 21:34:44.076069 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.076486 0x364e43000 feature_extraction.cc:257] Processed file [35/42]
# I20240818 21:34:44.076491 0x364e43000 feature_extraction.cc:260]   Name:            reconstruction/textured_reconstruction.obj
# E20240818 21:34:44.076494 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.076738 0x364e43000 feature_extraction.cc:257] Processed file [36/42]
# I20240818 21:34:44.076742 0x364e43000 feature_extraction.cc:260]   Name:            run-colmap-geometric.sh
# E20240818 21:34:44.076745 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.077020 0x364e43000 feature_extraction.cc:257] Processed file [37/42]
# I20240818 21:34:44.077026 0x364e43000 feature_extraction.cc:260]   Name:            run-colmap-photometric.sh
# E20240818 21:34:44.077030 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.077362 0x364e43000 feature_extraction.cc:257] Processed file [38/42]
# I20240818 21:34:44.077369 0x364e43000 feature_extraction.cc:260]   Name:            sparse/cameras.bin
# E20240818 21:34:44.077372 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.077755 0x364e43000 feature_extraction.cc:257] Processed file [39/42]
# I20240818 21:34:44.077762 0x364e43000 feature_extraction.cc:260]   Name:            sparse/images.bin
# E20240818 21:34:44.077765 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.078200 0x364e43000 feature_extraction.cc:257] Processed file [40/42]
# I20240818 21:34:44.078206 0x364e43000 feature_extraction.cc:260]   Name:            sparse/points3D.bin
# E20240818 21:34:44.078209 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.078353 0x364e43000 feature_extraction.cc:257] Processed file [41/42]
# I20240818 21:34:44.078361 0x364e43000 feature_extraction.cc:260]   Name:            stereo/fusion.cfg
# E20240818 21:34:44.078374 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.078471 0x364e43000 feature_extraction.cc:257] Processed file [42/42]
# I20240818 21:34:44.078479 0x364e43000 feature_extraction.cc:260]   Name:            stereo/patch-match.cfg
# E20240818 21:34:44.078482 0x364e43000 feature_extraction.cc:266] Failed to read image file format.
# I20240818 21:34:44.078867 0x3108eb000 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20240818 21:34:44.079666 0x3108eb000 misc.cc:198]
# ==============================================================================
# Feature matching
# ==============================================================================
# I20240818 21:34:44.079774 0x312d5b000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079778 0x312de7000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079791 0x312e73000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079819 0x314eff000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079846 0x32c97b000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079861 0x32ea13000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079872 0x330a9f000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079877 0x332b2b000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079888 0x332bb7000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079898 0x334de7000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079911 0x33ee73000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20240818 21:34:44.079917 0x344187000 sift.cc:1457] Creating SIFT CPU feature matcher
# I

# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 89
#      87 # Remove low-density vertices
#      88 print("Removing low-density vertices...")
# ---> 89 vertices_to_remove = mesh.remove_vertices_by_mask(mesh.vertex_density() < 0.01)
#      90 print(f"Removed {vertices_to_remove} low-density vertices")
#      92 # Simplify mesh
#
# AttributeError: 'open3d.cpu.pybind.geometry.TriangleMesh' object has no attribute 'vertex_density'

# %%
import os
import pycolmap
import numpy as np
import open3d as o3d

# Set the path to the dataset
dataset_path = "Datasets/fountain"

# Create a COLMAP database
database_path = os.path.join(dataset_path, "database.db")
db = pycolmap.Database(database_path)

# Configure SIFT feature extraction options
sift_options = pycolmap.SiftExtractionOptions()
sift_options.max_num_features = 8192
sift_options.first_octave = -1
sift_options.num_octaves = 4

# Configure image reader options
reader_options = pycolmap.ImageReaderOptions()

# Extract features
pycolmap.extract_features(database_path, dataset_path, image_list=[],
                          camera_mode=pycolmap.CameraMode.AUTO,
                          camera_model="OPENCV",
                          reader_options=reader_options,
                          sift_options=sift_options)

# Match features
pycolmap.match_exhaustive(database_path)

# Configure incremental mapping options
pipeline_options = pycolmap.IncrementalPipelineOptions()
pipeline_options.mapper.num_threads = 4
pipeline_options.mapper.init_min_num_inliers = 100
pipeline_options.mapper.abs_pose_min_num_inliers = 30
pipeline_options.mapper.abs_pose_min_inlier_ratio = 0.25

# Set up output path
output_path = os.path.join(dataset_path, "reconstruction")
os.makedirs(output_path, exist_ok=True)

# Run incremental mapping
reconstructions = pycolmap.incremental_mapping(database_path, dataset_path, output_path, options=pipeline_options)

if reconstructions:
    reconstruction = next(iter(reconstructions.values()))
    print(f"Reconstruction completed and saved to {output_path}")
    print(f"Number of registered images: {reconstruction.num_reg_images()}")
    print(f"Number of 3D points: {reconstruction.num_points3D()}")

    # Save reconstruction as text files
    reconstruction.write_text(output_path)

    # Prepare point cloud data
    points = []
    colors = []

    for point3D_id in reconstruction.points3D:
        point3D = reconstruction.points3D[point3D_id]
        points.append(point3D.xyz)
        colors.append(point3D.color)

    points = np.array(points)
    colors = np.array(colors)

    # Create Open3D point cloud
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(points)
    pcd.colors = o3d.utility.Vector3dVector(colors / 255.0)

    # Post-processing: downsampling and outlier removal
    pcd = pcd.voxel_down_sample(voxel_size=0.01)
    pcd, _ = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)

    # Estimate normals
    pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
    pcd.orient_normals_consistent_tangent_plane(100)

    # Visualize the point cloud (optional, for debugging)
    # o3d.visualization.draw_geometries([pcd])

    # Create mesh from point cloud
    print("Creating mesh from point cloud...")
    mesh, _ = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(pcd, depth=9)

    # Simplify mesh
    print("Simplifying mesh...")
    mesh = mesh.simplify_quadric_decimation(target_number_of_triangles=100000)

    # Estimate vertex normals for better visualization
    mesh.compute_vertex_normals()

    # Save mesh as OBJ file
    mesh_path = os.path.join(output_path, "reconstructed_mesh.obj")
    o3d.io.write_triangle_mesh(mesh_path, mesh)
    print(f"Mesh saved as: {mesh_path}")

    # Visualize the mesh
    print("Visualizing the mesh...")
    o3d.visualization.draw_geometries([mesh])

else:
    print("No reconstruction was created.")
# Out:
# E20240818 21:34:22.533201 0x1f5cd0f40 database.cc:263] SQLite error: unable to open database file
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 11
#       9 # Create a COLMAP database
#      10 database_path = os.path.join(dataset_path, "database.db")
# ---> 11 db = pycolmap.Database(database_path)
#      13 # Configure SIFT feature extraction options
#      14 sift_options = pycolmap.SiftExtractionOptions()
#
# RuntimeError: [database.cc:263] SQLite error: unable to open database file
